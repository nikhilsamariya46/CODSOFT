# %%
import random
import string
def generate_password(length):
    chars = string.ascii_letters + string.digits + "!@#$*"
    password =""
    for i in range(length):
       password += random.choice(chars)
    print(password)

generate_password(int (input("Enter password length (3-10): ")))
# Out:
# TCVME#kn
