# %%
num1 = int (input("What is the first integer"))
num2 = int (input("What is the second integer"))
operator_sign = input("the name of operator sign there is only four operator sign avaliable +,-,/,* ")
if operator_sign == "+":
    print(num1+num2)
if operator_sign == "-":
    print(num2-num1)
if operator_sign == "/":
    print (num1/num2)
if operator_sign == "*":
    print (num1*num2)
# Out:
# 30
